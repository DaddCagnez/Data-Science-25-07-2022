# %%
import pandas as pd
import pylab as plt 
import seaborn as sns
import numpy as np
from math import sqrt
from matplotlib import pyplot as plt
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %% [markdown]
# # Function Definition

# %%
# The p_value is returned to verify Stationarity
def p_value(df_value):
    result = adfuller(df_value.dropna())
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])

# %%
# Corelation and Differencing Plots (1 e 2).
def Differencing_Plot(df_value):  
    
    fig, axes = plt.subplots(3, 2, figsize=(8, 8))
    axes[0, 0].plot(df_value)
    axes[0, 0].set_title('Original Series')
    plot_acf(df_value, ax=axes[0, 1])

    axes[1, 0].plot(df_value.diff())
    axes[1, 0].set_title('1st Order Differencing')
    plot_acf(df_value.diff().dropna(), ax=axes[1, 1])

    axes[2, 0].plot(df_value.diff().diff())
    axes[2, 0].set_title('2nd Order Differencing')
    plot_acf(df_value.diff().diff().dropna(), ax=axes[2, 1])

    fig.tight_layout()
    return plt.show()

# %%
def Model_Creation(parTrain, parMax_p, parMax_q, parSeasonal):
    model = auto_arima(   parTrain,
                          start_p = 0,
                          start_q = 0,
                          information_criterion = 'aic',
                          test = 'adf',
                          max_p = parMax_p,
                          max_q = parMax_q,
                          D = 1,
                          start_P = 0,
                          m = 12,
                          seasonal = parSeasonal,
                          trace = True,
                          error_action = "ignore",
                          suppress_warnings = True,
                          stepwise = True,
                          verbose = 1)
    return model.summary()

# %%
# Allows you to perform the study using SARIMAX
# Moreover a what if analysis between test data and prediction is introduced 
# A1: First element for the order of arima
# A2: Second element for the order of arima
# A3: Third element for the order of arima
# S1: First element for Sarima's order
# S2: Second element for Sarima's order
# S3: Third element for the order of Sarima

def Sarimax_Execution(parTrain,parTest,parColumn,parSteps,A1,A2,A3,S1,S2,S3,parSeason):
  
    # Model Built
    model = SARIMAX(parTrain, order=(A1,A2,A3), seasonal_order=(S1,S2,S3,parSeason))
    
    # Fitting model
    results = model.fit()
    
    # Plot parameters
    plt.rcParams['figure.figsize'] = 12, 8
    plot = results.plot_diagnostics()

    # SARIMA - Prevision with Confidence Intervall
    forecast = results.get_forecast(steps = parSteps)
    lower = forecast.conf_int()["lower " + parColumn]
    upper = forecast.conf_int()["upper " + parColumn]
    fig,ax = plt.subplots(1,1,figsize=(20,10))

    plt.plot(parTrain, label='original',c='b')
    plt.plot(forecast.predicted_mean, label='SARIMAX', c="g")
    plt.plot(parTest, label='test',color='orange')
    plt.fill_between(forecast.conf_int().index,lower,upper,color='lightgray')
    plt.xlabel('Date')
    plt.ylabel('No of activated conracts')
    plt.legend()
    plt.show()

    return forecast

# %%
# Dynamic function to divide Dataset into testing and training set 
def Dynamic_Splitting (parDf,parColumn,parTrainSize):
    
    # Test e Train DataSet creation
    train_size = parTrainSize
    split_idx = round(len(Dismissals_Sondrio["SETTOREECONOMICO"])* train_size)

    # Split
    train = Dismissals_Sondrio.iloc[:split_idx]
    test = Dismissals_Sondrio.iloc[split_idx:]
    

    # Visualize split
    fig,ax= plt.subplots(figsize=(10,10))
    kws = dict(marker='o')
    plt.plot(train, label='Train', **kws)
    plt.plot(test, label='Test', **kws)
    ax.legend(bbox_to_anchor=[1,1]);
    
    return train, test

# %% [markdown]
# # Creation of the New DataSet for Time Serie

# %%
Dismissals = pd.read_csv('Lavori_Cessati_Cleaning.csv')

# %%
Dismissals_Sondrio = Dismissals.copy()

# %%
Dismissals_Sondrio.head(5)
# Out:
#          DATA GENERE  ETA                          SETTOREECONOMICODETTAGLIO  \
# 0  2021-03-11      M   55  Attività di famiglie e convivenze come datori ...
# 1  2021-05-03      M   55  Costruzione di edifici residenziali e non resi...
# 2  2021-05-12      M   34  Costruzione di edifici residenziali e non resi...
# 3  2019-04-08      M   27                  Ristorazione con somministrazione
# 4  2020-12-04      F   50  Attività di famiglie e convivenze come datori ...
#
#               TITOLOSTUDIO                     CONTRATTO  \
# 0  NESSUN TITOLO DI STUDIO              LAVORO DOMESTICO
# 1            LICENZA MEDIA    LAVORO A TEMPO DETERMINATO
# 2  NESSUN TITOLO DI STUDIO    LAVORO A TEMPO DETERMINATO
# 3            LICENZA MEDIA  LAVORO A TEMPO INDETERMINATO
# 4  NESSUN TITOLO DI STUDIO              LAVORO DOMESTICO
#
#                MODALITALAVORO PROVINCIAIMPRESA     TIPO  NAZIONE  ANNO  \
# 0  TEMPO PARZIALE ORIZZONTALE           MILANO  CESSATO  TUNISIA  2021
# 1                 TEMPO PIENO           MILANO  CESSATO   ITALIA  2021
# 2                 TEMPO PIENO           MILANO  CESSATO   EGITTO  2021
# 3  TEMPO PARZIALE ORIZZONTALE           MILANO  CESSATO   ITALIA  2019
# 4  TEMPO PARZIALE ORIZZONTALE           MILANO  CESSATO   ITALIA  2020
#
#    SETTOREECONOMICO
# 0                 4
# 1                 7
# 2                 7
# 3                 2
# 4                 4

# %% [markdown]
# ## Changing Columns Type

# %%
Dismissals_Sondrio['DATA'] = pd.to_datetime(Dismissals_Sondrio['DATA'])
Dismissals_Sondrio['SETTOREECONOMICO'] = pd.to_numeric(Dismissals_Sondrio['SETTOREECONOMICO'])

# %%
Dismissals_Sondrio.dtypes
# Out:
# DATA                         datetime64[ns]
# GENERE                               object
# ETA                                   int64
# SETTOREECONOMICODETTAGLIO            object
# TITOLOSTUDIO                         object
# CONTRATTO                            object
# MODALITALAVORO                       object
# PROVINCIAIMPRESA                     object
# TIPO                                 object
# NAZIONE                              object
# ANNO                                  int64
# SETTOREECONOMICO                      int64
# dtype: object

# %%
Dismissals_Sondrio.head()
# Out:
#         DATA GENERE  ETA                          SETTOREECONOMICODETTAGLIO  \
# 0 2021-03-11      M   55  Attività di famiglie e convivenze come datori ...
# 1 2021-05-03      M   55  Costruzione di edifici residenziali e non resi...
# 2 2021-05-12      M   34  Costruzione di edifici residenziali e non resi...
# 3 2019-04-08      M   27                  Ristorazione con somministrazione
# 4 2020-12-04      F   50  Attività di famiglie e convivenze come datori ...
#
#               TITOLOSTUDIO                     CONTRATTO  \
# 0  NESSUN TITOLO DI STUDIO              LAVORO DOMESTICO
# 1            LICENZA MEDIA    LAVORO A TEMPO DETERMINATO
# 2  NESSUN TITOLO DI STUDIO    LAVORO A TEMPO DETERMINATO
# 3            LICENZA MEDIA  LAVORO A TEMPO INDETERMINATO
# 4  NESSUN TITOLO DI STUDIO              LAVORO DOMESTICO
#
#                MODALITALAVORO PROVINCIAIMPRESA     TIPO  NAZIONE  ANNO  \
# 0  TEMPO PARZIALE ORIZZONTALE           MILANO  CESSATO  TUNISIA  2021
# 1                 TEMPO PIENO           MILANO  CESSATO   ITALIA  2021
# 2                 TEMPO PIENO           MILANO  CESSATO   EGITTO  2021
# 3  TEMPO PARZIALE ORIZZONTALE           MILANO  CESSATO   ITALIA  2019
# 4  TEMPO PARZIALE ORIZZONTALE           MILANO  CESSATO   ITALIA  2020
#
#    SETTOREECONOMICO
# 0                 4
# 1                 7
# 2                 7
# 3                 2
# 4                 4

# %%
Dismissals_Sondrio.PROVINCIAIMPRESA.unique()
# Out:
# array(['MILANO', 'SONDRIO'], dtype=object)

# %% [markdown]
# ## Rebuilding of the DataSet

# %%
Dismissals_Sondrio = Dismissals_Sondrio[['DATA', 'SETTOREECONOMICODETTAGLIO', 'SETTOREECONOMICO', 'PROVINCIAIMPRESA']]
Dismissals_Sondrio.head()
# Out:
#         DATA                          SETTOREECONOMICODETTAGLIO  \
# 0 2021-03-11  Attività di famiglie e convivenze come datori ...
# 1 2021-05-03  Costruzione di edifici residenziali e non resi...
# 2 2021-05-12  Costruzione di edifici residenziali e non resi...
# 3 2019-04-08                  Ristorazione con somministrazione
# 4 2020-12-04  Attività di famiglie e convivenze come datori ...
#
#    SETTOREECONOMICO PROVINCIAIMPRESA
# 0                 4           MILANO
# 1                 7           MILANO
# 2                 7           MILANO
# 3                 2           MILANO
# 4                 4           MILANO

# %%
Dismissals_Sondrio = Dismissals_Sondrio[Dismissals_Sondrio['PROVINCIAIMPRESA'] == 'SONDRIO']

# %%
Dismissals_Sondrio = Dismissals_Sondrio.groupby(pd.Grouper(key='DATA', axis=0, freq='M')).mean(numeric_only = True)

# %%
Dismissals_Sondrio.head()
# Out:
#             SETTOREECONOMICO
# DATA
# 2008-01-31               4.0
# 2008-02-29               2.0
# 2008-03-31               4.0
# 2008-04-30               4.0
# 2008-05-31               4.0

# %%
Dismissals_Sondrio.shape
# Out:
# (166, 1)

# %% [markdown]
# # Time Series

# %%
Dismissals_Sondrio.plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='DATA'>

# %% [markdown]
# ## Seasonality

# %% [markdown]
# Seasonality in time-series data refers to a pattern that occurs at a regular interval.

# %% [markdown]
# ### Multiplicative Seasonal Decompose

# %%
# Seasonal Variation Analyzing
plt.rcParams.update({'figure.figsize': (8,8)})
result_mul = seasonal_decompose(Dismissals_Sondrio['SETTOREECONOMICO'], model = 'multiplicative', period = 40)
decomposition_result = result_mul.plot()

# %% [markdown]
# ### Additive Seasonal Decompose

# %%
# Seasonal Variation Analyzing
plt.rcParams.update({'figure.figsize': (8,8)})
result_add = seasonal_decompose(Dismissals_Sondrio['SETTOREECONOMICO'], model = 'additive', period = 40)
decomposition_result = result_add.plot()

# %%
# ADF calculation
p_value(Dismissals_Sondrio["SETTOREECONOMICO"])
# Out:
# ADF Statistic: -2.681031
# p-value: 0.077379

# %%
# Differencing plots representation
Differencing_Plot(Dismissals_Sondrio["SETTOREECONOMICO"])

# %% [markdown]
# ## Stationarity

# %% [markdown]
# A stationary time series is a series whose statistical properties are independent of the point in time at which they are observed. This Means that Mean, variance and other statistics of a stationary time series remains constant.
# The p-value represents a probability of the error when expecting, that the trend differs from zero. Returning p_value to verify Stationarity.

# %%
# Time Serie Stationarity Verification (If p_value < 0.05)
p_value(Dismissals_Sondrio["SETTOREECONOMICO"].diff())
# Out:
# ADF Statistic: -6.233931
# p-value: 0.000000

# %% [markdown]
# ### Differencing

# %% [markdown]
# Differencing can help stabilize the mean of the time series by removing changes in the level of a time series, and so eliminating (or reducing) Trend and Seasonality.

# %% [markdown]
# ## Training and Testing Dataset

# %% [markdown]
# In this section Training and Testing Dataset are generated with the Dynamic Function "Dynamic_Splitting"

# %%
train, test = Dynamic_Splitting(Dismissals_Sondrio,"SETTOREECONOMICO",0.90)

# %% [markdown]
# ## SARIMAX Model Creation

# %% [markdown]
# In order to implement the Sarimax prediction model, it's necessary to find out the optimal model. For this reason, the function "Model_Creation" permits to discover the best configuration.

# %%
Model_Creation(train,6,6,True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : AIC=227.453, Time=0.12 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=262.737, Time=0.05 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=232.828, Time=0.13 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=227.423, Time=0.15 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=262.079, Time=0.04 sec
#  ARIMA(0,0,1)(0,1,0)[12] intercept   : AIC=263.244, Time=0.04 sec
#  ARIMA(0,0,1)(1,1,1)[12] intercept   : AIC=229.376, Time=0.29 sec
#  ARIMA(0,0,1)(0,1,2)[12] intercept   : AIC=229.393, Time=0.39 sec
#  ARIMA(0,0,1)(1,1,0)[12] intercept   : AIC=233.003, Time=0.13 sec
#  ARIMA(0,0,1)(1,1,2)[12] intercept   : AIC=230.756, Time=0.76 sec
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=225.724, Time=0.36 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=264.767, Time=0.13 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=227.279, Time=0.66 sec
#  ARIMA(1,0,1)(0,1,2)[12] intercept   : AIC=227.443, Time=0.87 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=231.531, Time=0.33 sec
#  ARIMA(1,0,1)(1,1,2)[12] intercept   : AIC=228.394, Time=1.31 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=227.119, Time=0.13 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=227.678, Time=0.64 sec
#  ARIMA(1,0,2)(0,1,1)[12] intercept   : AIC=227.675, Time=0.71 sec
#  ARIMA(0,0,2)(0,1,1)[12] intercept   : AIC=228.682, Time=0.18 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=228.343, Time=0.18 sec
#  ARIMA(2,0,2)(0,1,1)[12] intercept   : AIC=229.363, Time=0.72 sec
#  ARIMA(1,0,1)(0,1,1)[12]             : AIC=225.514, Time=0.26 sec
#  ARIMA(1,0,1)(0,1,0)[12]             : AIC=263.483, Time=0.04 sec
#  ARIMA(1,0,1)(1,1,1)[12]             : AIC=226.867, Time=0.35 sec
#  ARIMA(1,0,1)(0,1,2)[12]             : AIC=227.076, Time=0.54 sec
#  ARIMA(1,0,1)(1,1,0)[12]             : AIC=230.956, Time=0.23 sec
#  ARIMA(1,0,1)(1,1,2)[12]             : AIC=228.087, Time=0.98 sec
#  ARIMA(0,0,1)(0,1,1)[12]             : AIC=229.746, Time=0.09 sec
#  ARIMA(1,0,0)(0,1,1)[12]             : AIC=229.087, Time=0.13 sec
#  ARIMA(2,0,1)(0,1,1)[12]             : AIC=227.473, Time=0.43 sec
#  ARIMA(1,0,2)(0,1,1)[12]             : AIC=227.471, Time=0.29 sec
#  ARIMA(0,0,0)(0,1,1)[12]             : AIC=230.726, Time=0.06 sec
#  ARIMA(0,0,2)(0,1,1)[12]             : AIC=230.263, Time=0.15 sec
#  ARIMA(2,0,0)(0,1,1)[12]             : AIC=229.462, Time=0.14 sec
#  ARIMA(2,0,2)(0,1,1)[12]             : AIC=229.131, Time=0.48 sec
#
# Best model:  ARIMA(1,0,1)(0,1,1)[12]
# Total fit time: 12.500 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  149
# Model:             SARIMAX(1, 0, 1)x(0, 1, 1, 12)   Log Likelihood                -108.757
# Date:                            Tue, 05 Jul 2022   AIC                            225.514
# Time:                                    18:55:26   BIC                            237.194
# Sample:                                         0   HQIC                           230.260
#                                             - 149
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9526      0.067     14.249      0.000       0.822       1.084
# ma.L1         -0.8566      0.099     -8.691      0.000      -1.050      -0.663
# ma.S.L12      -0.7307      0.107     -6.838      0.000      -0.940      -0.521
# sigma2         0.2689      0.024     11.338      0.000       0.222       0.315
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                31.41
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.05   Skew:                            -0.24
# Prob(H) (two-sided):                  0.88   Kurtosis:                         5.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Numeric values represent:
# First: Number of Test Data
# Middle: the best SARIMAX model returned in the previous Cell
# Last: Periodicity

sarima_prediction = Sarimax_Execution(train,test,"SETTOREECONOMICO",17,1,0,1,0,1,1,12)
# Out:
# C:\Users\Alessandro\anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
# Metrics of Sarima Evalutation 
rmse = sqrt(mean_squared_error(test,sarima_prediction.predicted_mean))
print('RMSE: %f' % rmse)
# Out:
# RMSE: 0.775980

# %% [markdown]
# ## LSTM Forecasting

# %% [markdown]
# LSTM allows to predict the future values of a Time Serie adopting a Machine Learning approach

# %% [markdown]
# Before to start Training and Testing data are scaled. Here the minimum value n the dataset is subtracted of the features, then the elements into the dataset are divided from the Range (Max Value - Min Value)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
Dismissals_Sondrio.head(), Dismissals_Sondrio.tail()
# Out:
# (            SETTOREECONOMICO
#  DATA
#  2008-01-31               4.0
#  2008-02-29               2.0
#  2008-03-31               4.0
#  2008-04-30               4.0
#  2008-05-31               4.0,
#              SETTOREECONOMICO
#  DATA
#  2021-06-30          3.591837
#  2021-07-31          2.768595
#  2021-08-31          2.924370
#  2021-09-30          3.510638
#  2021-10-31          4.379310)

# %%
scaler.fit(train)
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
# Generator Definition for 12 month
from keras.preprocessing.sequence import TimeseriesGenerator

n_input = 12
n_features = 1
generator = TimeseriesGenerator(scaled_train, scaled_train, length = n_input, batch_size = 1)

# %%
X,y = generator[0]
print(f'Array: \n{X.flatten()}')
print(f'Prediction: \n{y}')
# Out:
# Array:
# [0.75293373 0.27680601 0.75293373 0.75293373 0.75293373 0.75293373
#  0.75293373 0.75293373 0.75293373 0.75293373 0.75293373 0.75293373]
# Prediction:
# [[0.75293373]]

# %%
X.shape  #N_Rows, N_Columns, N_Features
# Out:
# (1, 12, 1)

# %% [markdown]
# ## LSTM Model Implementation

# %% [markdown]
# At this point the LSTM model can be defined. Activation and Loss Functions are required, where the first has 'tanh' as default value, but in this case ReLU function is preferred to guarantee better quality to the neural unit (bounded, monotony, easy to handle)

# %%
# Model Definition
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

model = Sequential()
model.add(LSTM(100, activation = 'relu', input_shape = (n_input, n_features)))
model.add(Dense(1))
model.compile(optimizer = 'adam', loss = 'mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100)               40800
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 40,901
# Trainable params: 40,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(generator, epochs = 180)  #Epochs = Number of Iterations
# Out:
# Epoch 1/180
# 137/137 [==============================] - 2s 4ms/step - loss: 0.0476
# Epoch 2/180
# 137/137 [==============================] - 0s 4ms/step - loss: 0.0261
# Epoch 3/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0228
# Epoch 4/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0222
# Epoch 5/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0241
# Epoch 6/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0231
# Epoch 7/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0212
# Epoch 8/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0232
# Epoch 9/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0220
# Epoch 10/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0216
# Epoch 11/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0203
# Epoch 12/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0198
# Epoch 13/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0198
# Epoch 14/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0206
# Epoch 15/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0189
# Epoch 16/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0214
# Epoch 17/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0184
# Epoch 18/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0194
# Epoch 19/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0177
# Epoch 20/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0174
# Epoch 21/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0170
# Epoch 22/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0164
# Epoch 23/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0182
# Epoch 24/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0169
# Epoch 25/180
# 137/137 [==============================] - 0s 4ms/step - loss: 0.0177
# Epoch 26/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0170
# Epoch 27/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0171
# Epoch 28/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0173
# Epoch 29/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0165
# Epoch 30/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0171
# Epoch 31/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0169
# Epoch 32/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0164
# Epoch 33/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0167
# Epoch 34/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0183
# Epoch 35/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0162
# Epoch 36/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0160
# Epoch 37/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0178
# Epoch 38/180
# 137/137 [==============================] - 0s 4ms/step - loss: 0.0158
# Epoch 39/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0166
# Epoch 40/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0163
# Epoch 41/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0158
# Epoch 42/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0163
# Epoch 43/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0160
# Epoch 44/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0153
# Epoch 45/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0155
# Epoch 46/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0150
# Epoch 47/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0166
# Epoch 48/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0168
# Epoch 49/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0157
# Epoch 50/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0162
# Epoch 51/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0153
# Epoch 52/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0159
# Epoch 53/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0149
# Epoch 54/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0155
# Epoch 55/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0157
# Epoch 56/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0152
# Epoch 57/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0158
# Epoch 58/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0162
# Epoch 59/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0152
# Epoch 60/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0149
# Epoch 61/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0153
# Epoch 62/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0156
# Epoch 63/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0154
# Epoch 64/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0151
# Epoch 65/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0154
# Epoch 66/180
# 137/137 [==============================] - 0s 4ms/step - loss: 0.0149
# Epoch 67/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0153
# Epoch 68/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0150
# Epoch 69/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0159
# Epoch 70/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0151
# Epoch 71/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0155
# Epoch 72/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0149
# Epoch 73/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0144
# Epoch 74/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0161
# Epoch 75/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0152
# Epoch 76/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0152
# Epoch 77/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0157
# Epoch 78/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0145
# Epoch 79/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0154
# Epoch 80/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0155
# Epoch 81/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0159
# Epoch 82/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0149
# Epoch 83/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0154
# Epoch 84/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0151
# Epoch 85/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0156
# Epoch 86/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0150
# Epoch 87/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0151
# Epoch 88/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0154
# Epoch 89/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0154
# Epoch 90/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0148
# Epoch 91/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0148
# Epoch 92/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0154
# Epoch 93/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0148
# Epoch 94/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0150
# Epoch 95/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0152
# Epoch 96/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0148
# Epoch 97/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0153
# Epoch 98/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0156
# Epoch 99/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0157
# Epoch 100/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0147
# Epoch 101/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0151
# Epoch 102/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0146
# Epoch 103/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0151
# Epoch 104/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0150
# Epoch 105/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0144
# Epoch 106/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0149
# Epoch 107/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0147
# Epoch 108/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0147
# Epoch 109/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0150
# Epoch 110/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0154
# Epoch 111/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0149
# Epoch 112/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0146
# Epoch 113/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0155
# Epoch 114/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0152
# Epoch 115/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0151
# Epoch 116/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0153
# Epoch 117/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0159
# Epoch 118/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0149
# Epoch 119/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0158
# Epoch 120/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0149
# Epoch 121/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0146
# Epoch 122/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0147
# Epoch 123/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0141
# Epoch 124/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0150
# Epoch 125/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0149
# Epoch 126/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0150
# Epoch 127/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0146
# Epoch 128/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0142
# Epoch 129/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0153
# Epoch 130/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0143
# Epoch 131/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0164
# Epoch 132/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0152
# Epoch 133/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0149
# Epoch 134/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0151
# Epoch 135/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0155
# Epoch 136/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0154
# Epoch 137/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0162
# Epoch 138/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0151
# Epoch 139/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0149
# Epoch 140/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0146
# Epoch 141/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0149
# Epoch 142/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0146
# Epoch 143/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0143
# Epoch 144/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0147
# Epoch 145/180
# 137/137 [==============================] - 0s 4ms/step - loss: 0.0147
# Epoch 146/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0147
# Epoch 147/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0156
# Epoch 148/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0151
# Epoch 149/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0148
# Epoch 150/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0146
# Epoch 151/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0149
# Epoch 152/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0144
# Epoch 153/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0146
# Epoch 154/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0149
# Epoch 155/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0151
# Epoch 156/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0153
# Epoch 157/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0146
# Epoch 158/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0143
# Epoch 159/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0149
# Epoch 160/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0149
# Epoch 161/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0147
# Epoch 162/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0147
# Epoch 163/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0147
# Epoch 164/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0148
# Epoch 165/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0143
# Epoch 166/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0156
# Epoch 167/180
# 137/137 [==============================] - 0s 4ms/step - loss: 0.0148
# Epoch 168/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0145
# Epoch 169/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0152
# Epoch 170/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0139
# Epoch 171/180
# 137/137 [==============================] - 0s 4ms/step - loss: 0.0147
# Epoch 172/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0153
# Epoch 173/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0143
# Epoch 174/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0144
# Epoch 175/180
# 137/137 [==============================] - 0s 4ms/step - loss: 0.0143
# Epoch 176/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0148
# Epoch 177/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0146
# Epoch 178/180
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0143
# Epoch 179/180
# 137/137 [==============================] - 0s 4ms/step - loss: 0.0149
# Epoch 180/180
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0148

# %%
# Plot to analize value loss during epochs
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
last_train_batch = scaled_train[-12:]

# %%
last_train_batch = last_train_batch.reshape((1, n_input, n_features))

# %%
model.predict(last_train_batch)
# Out:
# 1/1 [==============================] - 0s 158ms/step
# array([[0.58305544]], dtype=float32)

# %%
scaled_test[0]
# Out:
# array([0.66845946])

# %%
test_predictions = []
first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    # Prediction value for First Batch
    current_prediction = model.predict(current_batch)[0] 
    # Append Prediction into the array
    test_predictions.append(current_prediction)          
    # Using Prediction to update batch, removing the first value 
    current_batch = np.append(current_batch[:,1:,:], [[current_prediction]], axis = 1)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step

# %%
test_predictions
# Out:
# [array([0.58305544], dtype=float32),
#  array([0.5720345], dtype=float32),
#  array([0.58572364], dtype=float32),
#  array([0.5817738], dtype=float32),
#  array([0.6153255], dtype=float32),
#  array([0.6195942], dtype=float32),
#  array([0.90856826], dtype=float32),
#  array([0.57851744], dtype=float32),
#  array([0.57910895], dtype=float32),
#  array([0.6097139], dtype=float32),
#  array([0.59997165], dtype=float32),
#  array([0.6765768], dtype=float32),
#  array([0.58805263], dtype=float32),
#  array([0.5824791], dtype=float32),
#  array([0.5833688], dtype=float32),
#  array([0.5825925], dtype=float32),
#  array([0.5895268], dtype=float32)]

# %%
test.head()
# Out:
#             SETTOREECONOMICO
# DATA
# 2020-06-30          3.645161
# 2020-07-31          2.920792
# 2020-08-31          3.440476
# 2020-09-30          3.432000
# 2020-10-31          3.316832

# %%
true_predictions= scaler.inverse_transform(test_predictions)

# %%
test['Predictions'] = true_predictions
# Out:
# C:\Users\ALESSA~1\AppData\Local\Temp/ipykernel_9428/4269337381.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions'] = true_predictions

# %%
test.head()
# Out:
#             SETTOREECONOMICO  Predictions
# DATA
# 2020-06-30          3.645161     3.286417
# 2020-07-31          2.920792     3.240123
# 2020-08-31          3.440476     3.297625
# 2020-09-30          3.432000     3.281034
# 2020-10-31          3.316832     3.421969

# %%
#test = test[['SETTOREECONOMICO', 'PREVISIONI']]

# %%
test.plot(figsize = (15,5))
# Out:
# <AxesSubplot:xlabel='DATA'>

# %%
rmse = sqrt(mean_squared_error(test['SETTOREECONOMICO'],test['Predictions']))
print(rmse)
# Out:
# 0.603220975873205
